# %%
import pandas as pd

# %%
df=pd.read_csv("2022SurveyData.csv")

# %%
df.head(2)
# Out:
#    ObjectID       1. Are you responding to this survey as:  \
# 0         1  Client of LMG Resilience & Community Services
# 1         2                                 General Public
#
#    2. In what zip code did you spend most of 2021?  \
# 0                                            40203
# 1                                            40205
#
#                         3. Community Need: Education  \
# 0  Affordable and high-quality childcare for pare...
# 1  Affordable and high-quality childcare for pare...
#
#                        4. Community Need: Employment  \
# 0             More jobs with better pay and benefits
# 1  Affordable and high-quality childcare for work...
#
#         5. Community Need: Income and Asset Building  \
# 0  Anonymous and confidential financial counselin...
# 1  Anonymous and confidential financial counselin...
#
#                  6. Community Need: Civic Engagement  \
# 0  More or better education on how to join neighb...
# ...

# %%
df["Year"]=2022
df.to_csv('df_2022.csv')

# %%
df.columns
# Out:
# Index(['ObjectID', '1. Are you responding to this survey as:',
#        '2. In what zip code did you spend most of 2021?',
#        '3. Community Need: Education', '4. Community Need: Employment',
#        '5. Community Need: Income and Asset Building',
#        '6. Community Need: Civic Engagement', '7. Community Need: Health',
#        '8. Community Need: Support Services that target',
#        '9. Community Need: OBTAINING Housing',
#        '10. Community Need: MAINTAINING Housing',
#        '11. Youth Services: (People under 18)',
#        '12. Senior Services: (People 55 or older)',
#        '13. Overall Most Needed in Community',
#        '14. How many people live in your household?',
#        '15. How many children (under 18) live with you?',
#        '16. Which best describes your housing presently?',
#        '17. What is your age?', '18. What gender do you identify as?',
#        '19. What is your Military Status?', '20. What is your ethnicity?',
# ...

# %%
df_F = df[(df["18. What gender do you identify as?"] == "Female")]
df_M = df[(df["18. What gender do you identify as?"] == "Male")]

# %%
#Store variables
var1='1. Are you responding to this survey as:'
var2 = '2. In what zip code did you spend most of 2021?'
var3='3. Community Need: Education'
var4='4. Community Need: Employment'
var5='5. Community Need: Income and Asset Building'
var6='6. Community Need: Civic Engagement'
var7='7. Community Need: Health'
var8= '8. Community Need: Support Services that target'
var9= '9. Community Need: OBTAINING Housing'
var10= '10. Community Need: MAINTAINING Housing'
var11='11. Youth Services: (People under 18)'
var12= '12. Senior Services: (People 55 or older)'
var13= '13. Overall Most Needed in Community'
var14='14. How many people live in your household?'
var15='15. How many children (under 18) live with you?'
var16= '16. Which best describes your housing presently?'
var17='17. What is your age?'
var18='18. What gender do you identify as?'
var19= '19. What is your Military Status?'
var20='20. What is your ethnicity?'
var21= '21. What is your race?'
var22= '22. What is the highest level of education you have completed?'
var23='23. What is your yearly household income?'
var24= '24. Which of the following best describes your current employment status?'

# %%
#survey by 
#var18='18. What gender do you identify as?'
df_18 = pd.DataFrame(df[var18].value_counts(dropna=True)).reset_index()
df_18.columns=[var18,"Counts"]
df_18["Year"]=2022
#df_1.to_csv('df_18.csv')
df_18
# Out:
#   18. What gender do you identify as?  Counts  Year
# 0                              Female    1156  2022
# 1                                Male     322  2022
# 2                Prefer not to Answer      49  2022
# 3                             Neither      23  2022

# %%
#Survey by :
# var21= '21. What is your race?'
df_21 = pd.DataFrame(df22[var21].value_counts(dropna=True)).reset_index()
df_21.columns=[var21,"Counts"]
df_21["Year"]=2022
#df_21.to_csv('df_21.csv')
df_21
# Out:
#                         21. What is your race?  Counts  Year
# 0                                        White     850  2022
# 1                       Black/African American     391  2022
# 2                         Prefer not to answer     207  2022
# 3       Multi-race (2 or more of the previous)      42  2022
# 4                                        Asian      16  2022
# 5                                        Other      12  2022
# 6             American Indian or Alaska Native       8  2022
# 7   American Indian or Alaska Native and White       8  2022
# 8   Native Hawaiian and Other Pacific Islander       8  2022
# 9   American Indian or Alaska Native and Black       6  2022
# 10                             Asian and White       3  2022

# %%
#Survey by :
#var1='1. Are you responding to this survey as:'
df_1 = pd.DataFrame(df[var1].value_counts(dropna=True)).reset_index()
df_1.columns=[var1,"Counts"]
df_1["Year"]=2022
#df_1.to_csv('df_1.csv')

# %%
df_1
# Out:
#         1. Are you responding to this survey as:  Counts  Year
# 0                                 General Public     995  2022
# 1      Community Service Provider/Agency Partner     267  2022
# 2  Client of LMG Resilience & Community Services     168  2022
# 3                      Louisville Metro Employee     123  2022

# %%
df_1.iloc[1,0]
# Out:
# 'Community Service Provider/Agency Partner'

# %%
#extract all the tables
#Survey by :
#var1='1. Are you responding to this survey as:'
df_1 = pd.DataFrame(df[var1].value_counts(dropna=True)).reset_index()
df_1.columns=[var1,"Counts1"]

#Survey by :
#var2='2. In what zip code did you spend most of 2021?'
df_2 = pd.DataFrame(df[var2].value_counts(dropna=True)).reset_index()
df_2.columns=[var2,"Counts2"]

#Survey by :
#var3='3. Community Need: Education'
df_3 = pd.DataFrame(df[var3].value_counts(dropna=True)).reset_index()
df_3.columns=[var3,"Counts3"]

#Survey by :
#var4='4. Community Need: Employment'
df_4 = pd.DataFrame(df[var4].value_counts(dropna=True)).reset_index()
df_4.columns=[var4,"Counts4"]

#Survey by :
#'5. Community Need: Income and Asset Building'
df_5 = pd.DataFrame(df[var5].value_counts(dropna=True)).reset_index()
df_5.columns=[var5,"Counts5"]

#Survey by :
#var1='6. Community Need: Civic Engagement'
df_6 = pd.DataFrame(df[var6].value_counts(dropna=True)).reset_index()
df_6.columns=[var6,"Counts6"]

#Survey by :
#'7. Community Need: Health'
df_7 = pd.DataFrame(df[var7].value_counts(dropna=True)).reset_index()
df_7.columns=[var7,"Counts7"]

#Survey by :
#var8= '8. Community Need: Support Services that target'
df_8 = pd.DataFrame(df[var8].value_counts(dropna=True)).reset_index()
df_8.columns=[var8,"Counts8"]

#Survey by :
#var9= '9. Community Need: OBTAINING Housing'
df_9 = pd.DataFrame(df[var9].value_counts(dropna=True)).reset_index()
df_9.columns=[var9,"Counts9"]

#Survey by :
#var10= '10. Community Need: MAINTAINING Housing'
df_10 = pd.DataFrame(df[var10].value_counts(dropna=True)).reset_index()
df_10.columns=[var10,"Counts10"]

#Survey by :
#var11='11. Youth Services: (People under 18)'
df_11 = pd.DataFrame(df[var11].value_counts(dropna=True)).reset_index()
df_11.columns=[var11,"Counts11"]

#var12= '12. Senior Services: (People 55 or older)'
df_12 = pd.DataFrame(df[var12].value_counts(dropna=True)).reset_index()
df_12.columns=[var12,"Counts12"]

#var13= '13. Overall Most Needed in Community'
df_13 = pd.DataFrame(df[var13].value_counts(dropna=True)).reset_index()
df_13.columns=[var13,"Counts13"]

#var14='14. How many people live in your household?'
df_14 = pd.DataFrame(df[var14].value_counts(dropna=True)).reset_index()
df_14.columns=[var14,"Counts14"]

#var15='15. How many children (under 18) live with you?'
df_15 = pd.DataFrame(df[var15].value_counts(dropna=True)).reset_index()
df_15.columns=[var15,"Counts15"]

#var16= '16. Which best describes your housing presently?'
df_16 = pd.DataFrame(df[var16].value_counts(dropna=True)).reset_index()
df_16.columns=[var16,"Counts16"]

#var17='17. What is your age?'
df_17 = pd.DataFrame(df[var17].value_counts(dropna=True)).reset_index()
df_17.columns=[var17,"Counts17"]

#var18='18. What gender do you identify as?'
df_18 = pd.DataFrame(df[var18].value_counts(dropna=True)).reset_index()
df_18.columns=[var18,"Counts18"]

#var19= '19. What is your Military Status?'
df_19 = pd.DataFrame(df[var19].value_counts(dropna=True)).reset_index()
df_19.columns=[var19,"Counts19"]

#var20='20. What is your ethnicity?'
df_20 = pd.DataFrame(df[var20].value_counts(dropna=True)).reset_index()
df_20.columns=[var20,"Counts20"]

#var21= '21. What is your race?'
df_21 = pd.DataFrame(df[var21].value_counts(dropna=True)).reset_index()
df_21.columns=[var21,"Counts21"]

#var22= '22. What is the highest level of education you have completed?'
df_22 = pd.DataFrame(df[var22].value_counts(dropna=True)).reset_index()
df_22.columns=[var22,"Counts22"]

#var23='23. What is your yearly household income?'
df_23 = pd.DataFrame(df[var23].value_counts(dropna=True)).reset_index()
df_23.columns=[var23,"Counts23"]

#var24= '24. Which of the following best describes your current employment status?'
df_24 = pd.DataFrame(df[var24].value_counts(dropna=True)).reset_index()
df_24.columns=[var24,"Counts24"]

# %%
# #export the tables
# df_1.to_csv('df_1.csv')
# df_2.to_csv('df_2.csv')
# df_3.to_csv('df_3.csv')
# df_4.to_csv('df_4.csv')
# df_5.to_csv('df_5.csv')
# df_6.to_csv('df_6.csv')
# df_7.to_csv('df_7.csv')
# df_8.to_csv('df_8.csv')
# df_9.to_csv('df_9.csv')
# df_10.to_csv('df_10.csv')
# df_11.to_csv('df_11.csv')
# df_12.to_csv('df_12.csv')
# df_13.to_csv('df_13.csv')
# df_14.to_csv('df_14.csv')
# df_15.to_csv('df_15.csv')
# df_16.to_csv('df_16.csv')
# df_17.to_csv('df_17.csv')
# df_18.to_csv('df_18.csv')
# df_19.to_csv('df_19.csv')
# df_20.to_csv('df_20.csv')
# df_21.to_csv('df_21.csv')
# df_22.to_csv('df_22.csv')
# df_23.to_csv('df_23.csv')
# df_24.to_csv('df_24.csv')

# %%
#Concatenate the tabels, except the zipcode column
dfc=pd.concat([df_1,df_3,df_4,df_5,df_6,df_7,df_8,df_9,df_10,df_11,df_12,df_13,df_14,df_15,df_16,df_17,df_18,df_19,df_20,df_21,df_22,df_23,df_24],axis=1)

# %%
df_3
# Out:
#                         3. Community Need: Education  Counts3  Year
# 0  More parents/guardians involved in students' e...      464  2022
# 1  Affordable and high-quality childcare for pare...      364  2022
# 2           More focus on vocation/college readiness      292  2022
# 3     More focus on preschool/kindergarten readiness      204  2022
# 4                                              Other      155  2022
# 5           Affordable transportation to/from school       55  2022

# %%
dfc
#dfc.to_csv('dfc.csv')
# Out:
#          1. Are you responding to this survey as:  Counts1    Year  \
# 0                                  General Public    995.0  2022.0
# 1       Community Service Provider/Agency Partner    267.0  2022.0
# 2   Client of LMG Resilience & Community Services    168.0  2022.0
# 3                       Louisville Metro Employee    123.0  2022.0
# 4                                             NaN      NaN     NaN
# 5                                             NaN      NaN     NaN
# 6                                             NaN      NaN     NaN
# 7                                             NaN      NaN     NaN
# 8                                             NaN      NaN     NaN
# 9                                             NaN      NaN     NaN
# 10                                            NaN      NaN     NaN
#
#                          3. Community Need: Education  Counts3    Year  \
# 0   More parents/guardians involved in students' e...    464.0  2022.0
# ...
